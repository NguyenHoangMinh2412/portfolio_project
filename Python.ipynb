# %% [markdown]
# Câu 1: Bạn hãy xây dựng một hàm nhận tham số truyền vào là 1 chuỗi ký tự bất kỳ. Hàm kiểm tra và trả về kết quả chuỗi trên là một đoạn password hợp lệ hay không, biết rằng password hợp lệ cần thoả mãn các tiêu chí:
#
# Chứa 1 ký tự đặc biệt trong các ký tự !, @, #, $, ^
#
# Chứa ít nhất một ký tự số
#
# Chứa ít nhất một ký tự chữ cái viết hoa
#
# Chứa ít nhất một ký tự chữ cái viết thường
#
# Độ dài từ 8 - 15 ký tự.

# %%
def kiem_tra(password):
    special_characters = ['!', '@', '#', '$', '^']
    if (len(password) < 8) or (len(password) > 15):
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char in special_characters for char in password):
        return False
    return True

password = input("Nhập vào mật khẩu: ")
if kiem_tra(password):
    print("Mật khẩu hợp lệ")
else:
    print("Mật khẩu không hợp lệ")
# Out:
# Nhập vào mật khẩu: qwe123@A
# Mật khẩu hợp lệ

# %% [markdown]
# Câu 3:  Bạn hãy xây dựng một hàm nhận tham số truyền vào là một danh sách bất kỳ chỉ chứa các số. Hàm tính toán và  trả về số lớn nhì trong danh sách. Với trường hợp danh sách gồm các số bằng nhau, hàm trả về số lớn nhất. Nếu có nhiều giá trị bằng số lớn nhì trong danh sách, hàm trả về 1 giá trị duy nhất.
#
# Ví dụ:
#
# Với danh sách [1,1,1,1,1,1] -> Hàm trả về 1
#
# Với danh sách [1,2,1,1,2,3] -> Hàm trả về 2

# %%
def so_lon_nhi(lst):

    # Xóa tất cả các giá trị trùng lặp trong danh sách
    danhsach = set(lst)

    # Nếu danh sách chỉ chứa giá trị bằng nhau, trả về giá trị đó
    if len(danhsach) == 1:
        return max(danhsach)

    # Nếu danh sách chứa ít nhất hai giá trị khác nhau, tính số lớn nhì
    else:

        # Sắp xếp danh sách giảm dần
        sapxep = sorted(danhsach, reverse=True)

        # Trả về giá trị thứ hai trong danh sách đã sắp xếp
        return sapxep[1]

# %%
lst = []
n = int(input("Nhập số lượng phần tử của danh sách: "))
for i in range(n):
    lst.append(int(input("Nhập giá trị phần tử thứ {} trong danh sách: ".format(i+1))))
print("Danh sách các số mà bạn đã nhập là: ", lst)
print("Số lớn nhì trong danh sách là: ", so_lon_nhi(lst))
# Out:
# Nhập số lượng phần tử của danh sách: 5
# Nhập giá trị phần tử thứ 1 trong danh sách: 1
# Nhập giá trị phần tử thứ 2 trong danh sách: 1
# Nhập giá trị phần tử thứ 3 trong danh sách: 1
# Nhập giá trị phần tử thứ 4 trong danh sách: 1
# Nhập giá trị phần tử thứ 5 trong danh sách: 1
# Danh sách các số mà bạn đã nhập là:  [1, 1, 1, 1, 1]
# Số lớn nhì trong danh sách là:  1

# %% [markdown]
# Câu 2: Bạn hãy đọc file dữ liệu với pandas. Và giải quyết các câu sau:
#
# Bạn hãy lấy ra các đơn hàng thuộc Branch A hoặc C
#
# Bạn hãy tìm ra các đơn hàng mua sản phẩm là ‘Health and beauty’ hoặc ‘Sports and travel’
#
# Cột InvoiceID, giá trị được lưu trữ theo dạng XXX-StoreID-XXXX.
#
# Bạn hãy tạo 1 dataframe mới gồm các cột như trên file và tạo thêm một cột StoreID được tách từ InvoiceID.Sau đó tính tổng doanh số của từng StoreID đó.

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/supermarket_sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date   Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08
# 1    Electronic accessories       15.28         5   3/8/2019  10:29
# 2        Home and lifestyle       46.33         7   3/3/2019  13:23
# ...

# %%
df_branch = df.loc[(df['Branch']=='A') | (df['Branch']=='C')]
df_branch
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date   Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08
# 1    Electronic accessories       15.28         5   3/8/2019  10:29
# 2        Home and lifestyle       46.33         7   3/3/2019  13:23
# ...

# %%
df_products = df.loc[(df['Product line']=='Health and beauty') | (df['Product line']=='Sports and travel')]
df_products
# Out:
#       Invoice ID Branch       City Customer type  Gender       Product line  \
# 0    750-67-8428      A     Yangon        Member  Female  Health and beauty
# 3    123-19-1176      A     Yangon        Member    Male  Health and beauty
# 4    373-73-7910      A     Yangon        Normal    Male  Sports and travel
# 8    665-32-9167      A     Yangon        Member  Female  Health and beauty
# 14   829-34-3910      A     Yangon        Normal  Female  Health and beauty
# ..           ...    ...        ...           ...     ...                ...
# 986  764-44-8999      B   Mandalay        Normal  Female  Health and beauty
# 987  552-44-5977      B   Mandalay        Member    Male  Health and beauty
# 989  430-53-4718      B   Mandalay        Member    Male  Health and beauty
# 991  602-16-6955      B   Mandalay        Normal  Female  Sports and travel
# 995  233-67-5758      C  Naypyitaw        Normal    Male  Health and beauty
#
# ...

# %%
df['StoreID'] = df['Invoice ID'].str.split('-').str[1]

df_sum = df.groupby('StoreID').sum()

df_sum
# Out:
# <ipython-input-38-4703eef387ea>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_sum = df.groupby('StoreID').sum()
#          Unit price  Quantity     cogs
# StoreID
# 01           797.10       104  5418.11
# 02           767.96        64  3864.69
# 03           627.02        79  4023.86
# 04           848.15        74  5441.09
# 05           537.43        50  2578.99
# ...             ...       ...      ...
# 95           643.01        48  3070.69
# 96           734.74        70  4681.04
# 97           437.25        15   916.60
# 98           591.73        59  3706.48
# 99           187.94        25  1627.19
#
# [99 rows x 3 columns]
